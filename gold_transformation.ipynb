# %%
import pandas as pd

# %% [markdown]
# # Load silver datasets

# %% [markdown]
# Load Alien Vault silver dataset.

# %%
df_alien_vault = pd.read_csv("silver/alien_vault/alien_vault.csv", sep=';')
df_alien_vault.head()
# Out:
#                             id  \
# 0  0.client-channel.google.com
# 1                  17track.net
# 2                     1drv.com
# 3    25z5g623wpqpdwis.onion.to
# 4  27lelchgcvs2wpm7.3lhjyx.top
#
#                                                names  \
# 0  23.219.89.169  dty-274d7ae9-e5e0-48eb-80db-f8d...
# 1  Remote Network Attack | JakyllHyde: Malicious ...
# 2  DarkWatchman Chekin Activity Order  Brian Sabe...
# 3  IOC Records Provided by @NextRayAI IOCs Indust...
# 4  TomkompSerwis   5b685b6fd0c356b8389e33596a40c6...
#
#                                         descriptions       TLPs threat_status
# 0   174.bm-nginx-loadbalancer.mgmt.sin1.adnexus.n...  ['white']     whitelist
# 1  Research shows compromise originated from Sabe...  ['green']     whitelist
# 2    Brian Sabey & large team continue excessive ...  ['green']     whitelist
# 3  This IOC report provided and daily updated by ...  ['white']     malicious
# 4  Dŵr dysku zewnętrznego wedi cymryd i'wodraeth ...  ['white']     malicious

# %% [markdown]
# Load VirusTotal silver dataset.

# %%
df_virus_total = pd.read_csv("silver/virus_total/virus_total.csv", sep=';')
df_virus_total.head()
# Out:
#                        root_id  \
# 0  0.client-channel.google.com
# 1                  17track.net
# 2                     1drv.com
# 3                 1fichier.com
# 4                     1und1.de
#
#                                                whois  reputation  tld  \
# 0  Creation Date: 1997-09-15T04:00:00Z\nCreation ...           0  com
# 1  Creation Date: 2011-03-09T01:44:43Z\nDNSSEC: u...           0  net
# 2  Creation Date: 2013-08-05T18:33:50+0000\nCreat...         -58  com
# 3  Admin City: REDACTED FOR PRIVACY\nAdmin Countr...           1  com
# 4  Changed: 2017-05-11T09:15:31+02:00\nDomain: 1u...           1   de
#
#                                            registrar  last_modification_date  \
# 0                                   MarkMonitor Inc.              1754931941
# 1  Alibaba Cloud Computing Ltd. d/b/a HiChina (ww...              1756732487
# 2                                   MarkMonitor Inc.              1756734594
# 3                                         ONLINE SAS              1756735976
# 4                                                NaN              1756733769
#
#    expiration_date  last_update_date  creation_date  stats_malicious  ...  \
# 0     1.852517e+09      1.722565e+09   8.743068e+08                0  ...
# 1     1.867711e+09      1.746083e+09   1.299635e+09                0  ...
# 2     1.785955e+09      1.751628e+09   1.375728e+09                0  ...
# 3     1.765109e+09      1.741239e+09   1.260188e+09                1  ...
# 4              NaN               NaN            NaN                0  ...
#
#    stats_undetected  stats_harmless  stats_timeout  votes_harmless  \
# 0                30              64              0               0
# 1                29              65              0               0
# 2                29              65              0               0
# 3                29              64              0               1
# 4                29              65              0               1
#
#    votes_malicious                               categories tags  \
# 0                0               ['harmless', 'undetected']  NaN
# 1                0               ['harmless', 'undetected']  NaN
# 2                4               ['harmless', 'undetected']  NaN
# 3                0  ['harmless', 'malicious', 'undetected']  NaN
# 4                0               ['harmless', 'undetected']  NaN
#
#   threat_status                            results  \
# 0     whitelist               ['clean', 'unrated']
# 1     whitelist               ['clean', 'unrated']
# 2     whitelist               ['clean', 'unrated']
# 3     whitelist  ['clean', 'unrated', 'malicious']
# 4     whitelist               ['clean', 'unrated']
#
#                                 ranks
# 0                            [992903]
# 1     [38944, 865, 10000, 1532, 9502]
# 2  [1000, 295850, 1873, 20789, 44693]
# 3   [20000, 647, 257267, 49174, 7513]
# 4          [5000, 5963, 23995, 10222]
#
# [5 rows x 21 columns]

# %% [markdown]
# # Merge datasets
# This code merges two DataFrames (`df_virus_total` and `df_alien_vault`) using the `root_id` column from the first and the `id` column from the second, creating a **combined DataFrame**.
#
# The `how="outer"` parameter specifies an **outer join**, meaning **all rows from both DataFrames are kept**; if there is no match, missing values are filled with `NaN`.

# %%
df_merged = pd.merge(
    df_virus_total,
    df_alien_vault,
    left_on="root_id",
    right_on="id",
    how="outer"
)

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Duplicate columns are removed, and columns are **renamed** to have **cleaner, more readable names**.

# %%
df_merged = df_merged.drop(['threat_status_x', 'id'], axis=1)

# %%
df_merged = df_merged.rename(columns={'root_id': 'id', 'threat_status_y': 'threat_status', 'TLPs': 'tlps'})

# %%
df_merged.columns
# Out:
# Index(['id', 'whois', 'reputation', 'tld', 'registrar',
#        'last_modification_date', 'expiration_date', 'last_update_date',
#        'creation_date', 'stats_malicious', 'stats_suspicious',
#        'stats_undetected', 'stats_harmless', 'stats_timeout', 'votes_harmless',
#        'votes_malicious', 'categories', 'tags', 'results', 'ranks', 'names',
#        'descriptions', 'tlps', 'threat_status'],
#       dtype='object')

# %%
df_merged.head()
# Out:
#                             id  \
# 0  0.client-channel.google.com
# 1                  17track.net
# 2                     1drv.com
# 3                 1fichier.com
# 4                     1und1.de
#
#                                                whois  reputation  tld  \
# 0  Creation Date: 1997-09-15T04:00:00Z\nCreation ...         0.0  com
# 1  Creation Date: 2011-03-09T01:44:43Z\nDNSSEC: u...         0.0  net
# 2  Creation Date: 2013-08-05T18:33:50+0000\nCreat...       -58.0  com
# 3  Admin City: REDACTED FOR PRIVACY\nAdmin Countr...         1.0  com
# 4  Changed: 2017-05-11T09:15:31+02:00\nDomain: 1u...         1.0   de
#
#                                            registrar  last_modification_date  \
# 0                                   MarkMonitor Inc.            1.754932e+09
# 1  Alibaba Cloud Computing Ltd. d/b/a HiChina (ww...            1.756732e+09
# 2                                   MarkMonitor Inc.            1.756735e+09
# 3                                         ONLINE SAS            1.756736e+09
# 4                                                NaN            1.756734e+09
#
#    expiration_date  last_update_date  creation_date  stats_malicious  ...  \
# 0     1.852517e+09      1.722565e+09   8.743068e+08              0.0  ...
# 1     1.867711e+09      1.746083e+09   1.299635e+09              0.0  ...
# 2     1.785955e+09      1.751628e+09   1.375728e+09              0.0  ...
# 3     1.765109e+09      1.741239e+09   1.260188e+09              1.0  ...
# 4              NaN               NaN            NaN              0.0  ...
#
#    votes_harmless  votes_malicious                               categories  \
# 0             0.0              0.0               ['harmless', 'undetected']
# 1             0.0              0.0               ['harmless', 'undetected']
# 2             0.0              4.0               ['harmless', 'undetected']
# 3             1.0              0.0  ['harmless', 'malicious', 'undetected']
# 4             1.0              0.0               ['harmless', 'undetected']
#
#    tags                            results  \
# 0   NaN               ['clean', 'unrated']
# 1   NaN               ['clean', 'unrated']
# 2   NaN               ['clean', 'unrated']
# 3   NaN  ['clean', 'unrated', 'malicious']
# 4   NaN               ['clean', 'unrated']
#
#                                 ranks  \
# 0                            [992903]
# 1     [38944, 865, 10000, 1532, 9502]
# 2  [1000, 295850, 1873, 20789, 44693]
# 3   [20000, 647, 257267, 49174, 7513]
# 4          [5000, 5963, 23995, 10222]
#
#                                                names  \
# 0  23.219.89.169  dty-274d7ae9-e5e0-48eb-80db-f8d...
# 1  Remote Network Attack | JakyllHyde: Malicious ...
# 2  DarkWatchman Chekin Activity Order  Brian Sabe...
# 3  IOC Records Provided by @NextRayAI IOCs Indust...
# 4                                                NaN
#
#                                         descriptions       tlps threat_status
# 0   174.bm-nginx-loadbalancer.mgmt.sin1.adnexus.n...  ['white']     whitelist
# 1  Research shows compromise originated from Sabe...  ['green']     whitelist
# 2    Brian Sabey & large team continue excessive ...  ['green']     whitelist
# 3  This IOC report provided and daily updated by ...  ['white']     whitelist
# 4                                                NaN        NaN           NaN
#
# [5 rows x 24 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3251 entries, 0 to 3250
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      499 non-null    object
#  1   whois                   496 non-null    object
#  2   reputation              499 non-null    float64
#  3   tld                     499 non-null    object
#  4   registrar               415 non-null    object
#  5   last_modification_date  499 non-null    float64
#  6   expiration_date         416 non-null    float64
#  7   last_update_date        416 non-null    float64
#  8   creation_date           416 non-null    float64
#  9   stats_malicious         499 non-null    float64
#  10  stats_suspicious        499 non-null    float64
#  11  stats_undetected        499 non-null    float64
#  12  stats_harmless          499 non-null    float64
#  13  stats_timeout           499 non-null    float64
#  14  votes_harmless          499 non-null    float64
#  15  votes_malicious         499 non-null    float64
#  16  categories              499 non-null    object
#  17  tags                    14 non-null     object
#  18  results                 499 non-null    object
#  19  ranks                   499 non-null    object
#  20  names                   3024 non-null   object
#  21  descriptions            1275 non-null   object
#  22  tlps                    3024 non-null   object
#  23  threat_status           3024 non-null   object
# dtypes: float64(12), object(12)
# memory usage: 609.7+ KB

# %% [markdown]
# # Save gold CSV

# %%
df_merged.to_csv('gold/gold.csv', sep=';', index=False)
