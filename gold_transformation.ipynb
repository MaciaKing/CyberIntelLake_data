# %%
import pandas as pd

# %% [markdown]
# # Load silver datasets

# %% [markdown]
# Load Alien Vault silver dataset.

# %%
df_alien_vault = pd.read_csv("silver/alien_vault/alien_vault.csv", sep=';')
df_alien_vault.head()
# Out:
#                             id  \
# 0  0.client-channel.google.com
# 1                  17track.net
# 2                     1drv.com
# 3    25z5g623wpqpdwis.onion.to
# 4  27lelchgcvs2wpm7.3lhjyx.top
#
#                                                names  \
# 0  23.219.89.169  dty-274d7ae9-e5e0-48eb-80db-f8d...
# 1  Remote Network Attack | JakyllHyde: Malicious ...
# 2  DarkWatchman Chekin Activity Order  Brian Sabe...
# 3  IOC Records Provided by @NextRayAI IOCs Indust...
# 4  TomkompSerwis   5b685b6fd0c356b8389e33596a40c6...
#
#                                         descriptions       TLPs threat_status
# 0   174.bm-nginx-loadbalancer.mgmt.sin1.adnexus.n...  ['white']     whitelist
# 1  Research shows compromise originated from Sabe...  ['green']     whitelist
# 2    Brian Sabey & large team continue excessive ...  ['green']     whitelist
# 3  This IOC report provided and daily updated by ...  ['white']     malicious
# 4  Dŵr dysku zewnętrznego wedi cymryd i'wodraeth ...  ['white']     malicious

# %% [markdown]
# Load VirusTotal silver dataset.

# %%
df_virus_total = pd.read_csv("silver/virus_total/virus_total.csv", sep=';')
df_virus_total.head()
# Out:
#                     root_id  \
# 0              imagebam.com
# 1         images-amazon.com
# 2           images.dmca.com
# 3          images.dwell.com
# 4  images.netdirector.co.uk
#
#                                                whois  reputation    tld  \
# 0  Admin City: Praha 4\nAdmin Country: CZ\nAdmin ...           0    com
# 1  Creation Date: 2004-07-20T23:52:20+0000\nCreat...           0    com
# 2  Creation Date: 2000-05-18T12:11:02Z\nDNSSEC: u...           0    com
# 3  Creation Date: 1999-03-18T05:00:00Z\nDNSSEC: u...           0    com
# 4  Expiry date: 25-Nov-2026\nLast updated: 07-Oct...           0  co.uk
#
#                       registrar  last_modification_date  expiration_date  \
# 0  GRANSY S.R.O D/B/A SUBREG.CZ            1.757077e+09     1.758527e+09
# 1              MarkMonitor Inc.            1.757080e+09     1.776312e+09
# 2              GoDaddy.com, LLC            1.757082e+09     2.031567e+09
# 3               NameCheap, Inc.            1.757001e+09     1.981432e+09
# 4                           NaN            1.757068e+09              NaN
#
#    last_update_date  creation_date  stats_malicious  ...  stats_timeout  \
# 0      1.726741e+09   1.158911e+09                1  ...              0
# 1      1.738346e+09   1.090368e+09                0  ...              0
# 2      1.732726e+09   9.586519e+08                0  ...              0
# 3      1.665813e+09   9.217332e+08                0  ...              0
# 4               NaN            NaN                0  ...              0
#
#    votes_harmless  votes_malicious  tags  threat_status  malware phishing  \
# 0               0                0   NaN      whitelist        0        0
# 1               0                0   NaN      whitelist        0        0
# 2               0                0   NaN      whitelist        0        0
# 3               0                0   NaN      whitelist        0        0
# 4               0                0   NaN      whitelist        0        0
#
#   not recommended  spam                              ranks
# 0               0     0  [1152, 20000, 176451, 4872, 8212]
# 1               0     0        [5000, 20354, 273404, 3166]
# 2               0     0                            [17899]
# 3               0     0                   [491648, 770756]
# 4               0     0                           [240790]
#
# [5 rows x 23 columns]

# %% [markdown]
# # Merge datasets
# This code merges two DataFrames (`df_virus_total` and `df_alien_vault`) using the `root_id` column from the first and the `id` column from the second, creating a **combined DataFrame**.
#
# The `how="outer"` parameter specifies an **outer join**, meaning **all rows from both DataFrames are kept**; if there is no match, missing values are filled with `NaN`.

# %%
df_merged = pd.merge(
    df_virus_total,
    df_alien_vault,
    left_on="root_id",
    right_on="id",
    how="inner"
)

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Duplicate columns are removed, and columns are **renamed** to have **cleaner, more readable names**.

# %%
df_merged = df_merged.drop(['threat_status_x', 'id'], axis=1)

# %%
df_merged = df_merged.rename(columns={'root_id': 'id', 'threat_status_y': 'threat_status', 'TLPs': 'tlps'})

# %%
df_merged.columns
# Out:
# Index(['id', 'whois', 'reputation', 'tld', 'registrar',
#        'last_modification_date', 'expiration_date', 'last_update_date',
#        'creation_date', 'stats_malicious', 'stats_suspicious',
#        'stats_undetected', 'stats_harmless', 'stats_timeout', 'votes_harmless',
#        'votes_malicious', 'tags', 'malware', 'phishing', 'not recommended',
#        'spam', 'ranks', 'names', 'descriptions', 'tlps', 'threat_status'],
#       dtype='object')

# %%
df_merged.head()
# Out:
#                       id                                              whois  \
# 0      images-amazon.com  Creation Date: 2004-07-20T23:52:20+0000\nCreat...
# 1        images.dmca.com  Creation Date: 2000-05-18T12:11:02Z\nDNSSEC: u...
# 2  imasdk.googleapis.com  Creation Date: 2005-01-25T08:00:00+0000\nCreat...
# 3             imgbox.com  Admin City: Praha 4\nAdmin Country: CZ\nAdmin ...
# 4              imgix.net  Admin City: REDACTED FOR PRIVACY\nAdmin Countr...
#
#    reputation  tld                     registrar  last_modification_date  \
# 0           0  com              MarkMonitor Inc.            1.757080e+09
# 1           0  com              GoDaddy.com, LLC            1.757082e+09
# 2          -1  com              MarkMonitor Inc.            1.757081e+09
# 3          -1  com  GRANSY S.R.O D/B/A SUBREG.CZ            1.757076e+09
# 4           0  net                     GANDI SAS            1.757083e+09
#
#    expiration_date  last_update_date  creation_date  stats_malicious  ...  \
# 0     1.776312e+09      1.738346e+09   1.090368e+09                0  ...
# 1     2.031567e+09      1.732726e+09   9.586519e+08                0  ...
# 2     1.769364e+09      1.735035e+09   1.106676e+09                0  ...
# 3     1.770666e+09      1.742947e+09   1.717286e+09                0  ...
# 4     1.845338e+09      1.747697e+09   1.308794e+09                0  ...
#
#    tags  malware  phishing  not recommended  spam  \
# 0   NaN        0         0                0     0
# 1   NaN        0         0                0     0
# 2   NaN        0         0                0     0
# 3   NaN        0         0                0     0
# 4   NaN        0         0                0     0
#
#                               ranks  \
# 0       [5000, 20354, 273404, 3166]
# 1                           [17899]
# 2               [26255, 23430, 567]
# 3  [5517, 5040, 10000, 7220, 66875]
# 4   [3808, 11204, 1733, 2000, 6324]
#
#                                                names  \
# 0  icon.palantirfoundry.com - Brazzers Porn Remot...
# 1  Android Remotely Cracked: Swipper? | Being Sab...
# 2  WhinySuckBaby The Best Buy Virus - Spreads Via...
# 3  Foundry • Reflected Networks Pornhub Malvertis...
# 4  Endgame 4 | ThreatIntelligence | Pegasus | Gra...
#
#                                         descriptions                tlps  \
# 0  Another strange pulse. Persistent bad actors m...  ['green', 'white']
# 1  Targets phone and other devices cracked remote...           ['green']
# 2  Files from a Virus that has plagued my life fo...  ['green', 'white']
# 3  Foundry ?  Pornhub\nsanfoundry.com\ncompliance...  ['green', 'white']
# 4  Do not access iOCs under any circumstances, ex...  ['green', 'white']
#
#    threat_status
# 0      whitelist
# 1      whitelist
# 2      whitelist
# 3      whitelist
# 4      whitelist
#
# [5 rows x 26 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3021 entries, 0 to 3020
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3021 non-null   object
#  1   whois                   1328 non-null   object
#  2   reputation              3021 non-null   int64
#  3   tld                     3021 non-null   object
#  4   registrar               1117 non-null   object
#  5   last_modification_date  3021 non-null   float64
#  6   expiration_date         1095 non-null   float64
#  7   last_update_date        1149 non-null   float64
#  8   creation_date           1149 non-null   float64
#  9   stats_malicious         3021 non-null   int64
#  10  stats_suspicious        3021 non-null   int64
#  11  stats_undetected        3021 non-null   int64
#  12  stats_harmless          3021 non-null   int64
#  13  stats_timeout           3021 non-null   int64
#  14  votes_harmless          3021 non-null   int64
#  15  votes_malicious         3021 non-null   int64
#  16  tags                    1822 non-null   object
#  17  malware                 3021 non-null   int64
#  18  phishing                3021 non-null   int64
#  19  not recommended         3021 non-null   int64
#  20  spam                    3021 non-null   int64
#  21  ranks                   3021 non-null   object
#  22  names                   3021 non-null   object
#  23  descriptions            1272 non-null   object
#  24  tlps                    3021 non-null   object
#  25  threat_status           3021 non-null   object
# dtypes: float64(4), int64(12), object(10)
# memory usage: 613.8+ KB

# %%
df_merged['threat_status'].value_counts()
# Out:
# threat_status
# malicious    1879
# whitelist    1142
# Name: count, dtype: int64

# %% [markdown]
# # Save gold CSV

# %%
df_merged.to_csv('gold/gold.csv', sep=';', index=False)
